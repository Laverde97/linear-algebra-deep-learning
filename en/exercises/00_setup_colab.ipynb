# %% [markdown]
# # 00 · Google Colab Setup
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Laverde97/linear-algebra-deep-learning/blob/main/en/exercises/00_setup_colab.ipynb)
#
# **Goal:** understand the concept, see it with numbers, and connect it to AI/deep learning. Run the cells in order.

# %% [markdown]
# ## How to work
#
# 1. Open the notebook with the **Open in Colab** button.
# 2. Run each cell with `Shift + Enter`.
# 3. In Colab, you can enable a GPU under **Runtime > Change runtime type > T4 GPU**.
# 4. The labs use NumPy as a foundation and compare TensorFlow/PyTorch when useful.

# %%
# !pip -q install tensorflow-datasets

# %%
import sys, platform, numpy as np
print("Python:", sys.version.split()[0])
print("Sistema:", platform.platform())
print("NumPy:", np.__version__)

# %%
import tensorflow as tf
import torch
print("TensorFlow:", tf.__version__)
print("TF GPU:", tf.config.list_physical_devices("GPU"))
print("PyTorch:", torch.__version__)
print("Torch CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %% [markdown]
# ### Shape reading rule
#
# - `(100,)` → vector with 100 elements.
# - `(100, 4)` → matrix: 100 rows × 4 columns.
# - `(32, 224, 224, 3)` → batch of 32 RGB images.
#
# **Shape** will be our shared language throughout the class.
