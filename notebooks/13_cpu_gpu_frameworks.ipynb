# %% [markdown]
# # Apéndice · Tensores en CPU/GPU: NumPy, TensorFlow y PyTorch
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Laverde97/linear-algebra-deep-learning-quarto/blob/main/notebooks/13_cpu_gpu_frameworks.ipynb)
#
# **Objetivo:** comprender el concepto, verlo con números y conectarlo con IA/deep learning. Ejecuta las celdas en orden.

# %% [markdown]
# ## Objetivo
#
# Comparar la misma operación matricial en tres marcos. No buscamos un benchmark científico; buscamos ver **dispositivo, forma y transferencia**.

# %%
import time, numpy as np, tensorflow as tf, torch
N=1500
A=np.random.randn(N,N).astype('float32')
B=np.random.randn(N,N).astype('float32')
print("TF GPU:",tf.config.list_physical_devices('GPU'))
print("Torch CUDA:",torch.cuda.is_available())

# %% [markdown]
# ## NumPy — CPU

# %%
t=time.perf_counter(); C=A@B; dt=time.perf_counter()-t
print(f"NumPy CPU: {dt:.3f}s | {C.shape}")

# %% [markdown]
# ## TensorFlow — el runtime elige CPU/GPU disponible

# %%
A_tf=tf.constant(A); B_tf=tf.constant(B)
t=time.perf_counter(); C_tf=tf.matmul(A_tf,B_tf); _=C_tf.numpy(); dt=time.perf_counter()-t
print(f"TensorFlow: {dt:.3f}s | {C_tf.shape} | {C_tf.device}")

# %% [markdown]
# ## PyTorch — mover explícitamente al dispositivo

# %%
device='cuda' if torch.cuda.is_available() else 'cpu'
A_t=torch.from_numpy(A).to(device); B_t=torch.from_numpy(B).to(device)
if device=='cuda': torch.cuda.synchronize()
t=time.perf_counter(); C_t=A_t@B_t
if device=='cuda': torch.cuda.synchronize()
dt=time.perf_counter()-t
print(f"PyTorch {device}: {dt:.3f}s | {tuple(C_t.shape)}")

# %% [markdown]
# ### Mensaje de clase
#
# El álgebra es la misma. Lo que cambia entre frameworks es la API, la gestión de dispositivos, autograd y el ecosistema. Las GPU son especialmente eficientes al ejecutar muchas operaciones tensoriales en paralelo.
