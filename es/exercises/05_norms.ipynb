# %% [markdown]
# # 2.5 · Normas
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Laverde97/linear-algebra-deep-learning/blob/main/es/exercises/05_norms.ipynb)
#
# **Objetivo:** comprender el concepto, verlo con números y conectarlo con IA/deep learning. Ejecuta las celdas en orden.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
print("NumPy:", np.__version__)

# %% [markdown]
# ## Medir el “tamaño” de un vector

# %%
x = np.array([3.,-4.,2.])
print("L1:", np.linalg.norm(x,1))
print("L2:", np.linalg.norm(x,2))
print("L∞:", np.linalg.norm(x,np.inf))

# %% [markdown]
# ## Norma de Frobenius para matrices

# %%
A = np.array([[1.,2.],[3.,4.]])
print("Frobenius:", np.linalg.norm(A,'fro'))
print("sqrt(sum squares):", np.sqrt(np.sum(A**2)))

# %% [markdown]
# ## Distancia entre dos imágenes MNIST

# %%
from tensorflow.keras.datasets import mnist
(x_train,y_train),_ = mnist.load_data()
a=x_train[0].astype(float)/255
b=x_train[1].astype(float)/255
print("Etiquetas:", y_train[0], y_train[1])
print("Distancia L2:", np.linalg.norm((a-b).ravel(),2))
print("Distancia L1:", np.linalg.norm((a-b).ravel(),1))

# %%
plt.figure(figsize=(6,3))
plt.subplot(1,2,1); plt.imshow(a,cmap='gray'); plt.title(str(y_train[0])); plt.axis('off')
plt.subplot(1,2,2); plt.imshow(b,cmap='gray'); plt.title(str(y_train[1])); plt.axis('off')
plt.show()

# %% [markdown]
# ## Regularización: intuición
#
# L1 tiende a favorecer muchos pesos exactamente pequeños/cero; L2 penaliza pesos grandes de forma suave.

# %%
weights = np.array([0.1, -0.2, 2.5, -3.0, 0.05])
print("Penalización L1:", np.linalg.norm(weights,1))
print("Penalización L2²:", np.linalg.norm(weights,2)**2)
