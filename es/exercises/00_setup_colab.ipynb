# %% [markdown]
# # 00 · Preparación de Google Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Laverde97/linear-algebra-deep-learning/blob/main/es/exercises/00_setup_colab.ipynb)
#
# **Objetivo:** comprender el concepto, verlo con números y conectarlo con IA/deep learning. Ejecuta las celdas en orden.

# %% [markdown]
# ## Cómo trabajar
#
# 1. Abre el notebook con el botón **Open in Colab**.
# 2. Ejecuta cada celda con `Shift + Enter`.
# 3. En Colab puedes activar GPU en **Runtime > Change runtime type > T4 GPU**.
# 4. Los laboratorios usan NumPy como base y comparan TensorFlow/PyTorch cuando aporta valor.

# %%
# !pip -q install tensorflow-datasets

# %%
import sys, platform, numpy as np
print("Python:", sys.version.split()[0])
print("Sistema:", platform.platform())
print("NumPy:", np.__version__)

# %%
import tensorflow as tf
import torch
print("TensorFlow:", tf.__version__)
print("TF GPU:", tf.config.list_physical_devices("GPU"))
print("PyTorch:", torch.__version__)
print("Torch CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %% [markdown]
# ### Regla de lectura de formas
#
# - `(100,)` → vector con 100 elementos.
# - `(100, 4)` → matriz: 100 filas × 4 columnas.
# - `(32, 224, 224, 3)` → lote de 32 imágenes RGB.
#
# La **forma** (`shape`) será nuestro lenguaje común durante toda la clase.
